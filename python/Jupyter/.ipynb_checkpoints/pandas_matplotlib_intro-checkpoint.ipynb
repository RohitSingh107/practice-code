# %%
import pandas as pd
import numpy as np
from random import randint
import json
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

# %%
df = pd.DataFrame()

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1 = pd.DataFrame([[randint(0,99) for x in range(0,6)] for i in range(0,10)], columns=['A', 'B', 'C', 'D', 'E', 'F'])

# %%
df1
# Out:
#     A   B   C   D   E   F
# 0  38  87  65  25  93  73
# 1  15  51  57  19  84   4
# 2  88  82   7  25  99  44
# 3  28  83  28  45  94  19
# 4  36  85  99  48  63  49
# 5  22   5  53  34  50  46
# 6  59  30  16  71  89  60
# 7  60  70  24  29  33  47
# 8  36  38  20  11   3  23
# 9  86   8  51  72  23   5

# %%
df1.head()
# Out:
#     A   B   C   D   E   F
# 0  38  87  65  25  93  73
# 1  15  51  57  19  84   4
# 2  88  82   7  25  99  44
# 3  28  83  28  45  94  19
# 4  36  85  99  48  63  49

# %%
df1.tail()
# Out:
#     A   B   C   D   E   F
# 5  22   5  53  34  50  46
# 6  59  30  16  71  89  60
# 7  60  70  24  29  33  47
# 8  36  38  20  11   3  23
# 9  86   8  51  72  23   5

# %%
df1.shape
# Out:
# (10, 6)

# %%
df1
# Out:
#     A   B   C   D   E   F
# 0  38  87  65  25  93  73
# 1  15  51  57  19  84   4
# 2  88  82   7  25  99  44
# 3  28  83  28  45  94  19
# 4  36  85  99  48  63  49
# 5  22   5  53  34  50  46
# 6  59  30  16  71  89  60
# 7  60  70  24  29  33  47
# 8  36  38  20  11   3  23
# 9  86   8  51  72  23   5

# %%
df1.iloc[6:9, 3:5]
# Out:
#     D   E
# 6  71  89
# 7  29  33
# 8  11   3

# %%
df1.to_csv("exported.csv", index=False)

# %%
df2 = pd.DataFrame([[randint(0,99) for x in range(0,6)] for i in range(0,10)], columns=['U', 'V', 'W', 'X', 'Y', 'Z'])

# %%
df1
# Out:
#     A   B   C   D   E   F
# 0  38  87  65  25  93  73
# 1  15  51  57  19  84   4
# 2  88  82   7  25  99  44
# 3  28  83  28  45  94  19
# 4  36  85  99  48  63  49
# 5  22   5  53  34  50  46
# 6  59  30  16  71  89  60
# 7  60  70  24  29  33  47
# 8  36  38  20  11   3  23
# 9  86   8  51  72  23   5

# %%
df2
# Out:
#     U   V   W   X   Y   Z
# 0  40  30  19  36  62   2
# 1  88  63  40  69  28  71
# 2  25  24   3   5  12  33
# 3  24  46   7  20  86  48
# 4  91  61  22  77   0  91
# 5   2  63   4  88  24  77
# 6  36  17  46  61  53  74
# 7  37  48  39  71  36   7
# 8  70  12  72  30  87   4
# 9  45  21  30   8   6  31

# %%
df3 = pd.DataFrame([[4,7,6], [1,45,23], [78,32,56]], columns = ['A', 'B', 'C'])

# %%
df3
# Out:
#     A   B   C
# 0   4   7   6
# 1   1  45  23
# 2  78  32  56

# %%
df4 = pd.DataFrame([[4,454,67], [1,332,2], [78,74,6]], columns = ['X', 'Y', 'Z'])

# %%
df4
# Out:
#     X    Y   Z
# 0   4  454  67
# 1   1  332   2
# 2  78   74   6

# %%
df5 = pd.merge(df3, df4, right_on = 'X', left_on = 'A')

# %%
df5
# Out:
#     A   B   C   X    Y   Z
# 0   4   7   6   4  454  67
# 1   1  45  23   1  332   2
# 2  78  32  56  78   74   6

# %%
json_data = '{"a": 4, "b": 7, "c": 9}'

# %%
x = json.loads(json_data)

# %%
x
# Out:
# {'a': 4, 'b': 7, 'c': 9}

# %%
x['a']
# Out:
# 4

# %%
with open('python_json.json', 'w') as f:
    json.dump(x, f)

# %%
style.use("ggplot")
plt.plot([4,2,5], [1,3,2], label = "First")
plt.plot([3,4,1], [4,2,5], label = "Second")
plt.legend()
plt.show()
